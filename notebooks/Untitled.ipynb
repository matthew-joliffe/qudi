# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
loc = 'C:/Data/2020/09/20200925/ODMR/20200925-0902-56_site_1_11_14_high_res_m21dBm_15uW_long_MW1_final_ODMR_data_ch0.dat'
data = np.loadtxt(loc)
x = data[:,0]
y = data[:,1]

# %%
plt.figure(figsize=(16,8))
plt.plot(x,y)

# %%
peak_1_start = 200
peak_1_finish = 300
x_peak1 = data[peak_1_start:peak_1_finish,0]
y_peak1 = data[peak_1_start:peak_1_finish,1]
plt.figure(figsize=(16,8))
plt.plot(x_peak1,y_peak1)

# %%
peak_2_start = 500
peak_2_finish = 700
x_peak2 = data[peak_2_start:peak_2_finish,0]
y_peak2 = data[peak_2_start:peak_2_finish,1]
plt.figure(figsize=(16,8))
plt.plot(x_peak2,y_peak2)

# %%
peak_3_start = 1000
peak_3_finish = 1150
x_peak3 = data[peak_3_start:peak_3_finish,0]
y_peak3 = data[peak_3_start:peak_3_finish,1]
plt.figure(figsize=(16,8))
plt.plot(x_peak3,y_peak3)

# %%
peak_4_start = 1300
peak_4_finish = 1500
x_peak4 = data[peak_4_start:peak_4_finish,0]
y_peak4 = data[peak_4_start:peak_4_finish,1]
plt.figure(figsize=(16,8))
plt.plot(x_peak4,y_peak4)
